# %%
# !pip install spotify
# Out:
# ...
#      ---------------------------------------- 46.4/46.4 kB 1.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install spotify
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# ...
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip3 install spotipy
# Out:
# ...
#      ------------------------------------ 238.5/238.5 kB 280.7 kB/s eta 0:00:00
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
import pandas as pd
import numpy as np

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='0b569aed504245e39f14cd38ba42c713', client_secret='74a4ed71fe9d4cd09822abfef5e38fb9')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlists = sp.user_playlists('spotify')

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'KAROL G & Shakira are on top of the Hottest 50!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#    'id': '37i9dQZF1DXcBWIGoYBM5M',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003204b059d8f9f285acb95da6a',
#      'width': None}],
#    'name': "Today's Top Hits",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTY3NzgxOTYwMCwwMDAwMDAwMDY5NGM1MWY3YmQwZTJmN2Y4NGY2ODJkZGYzMDg4OGI0',
# ...

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'

# %%
playlist_URI = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-03-03T10:15:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2023-03-03T10:15:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7I0tjwFtxUwBC1vgyeMAax'

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Miley Cyrus'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Flowers'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-01-13'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'

# %%
album_details = []
for row in data['items']:
    album_id=row['track']['album']['id']
    
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    
    album_element = {'album_id':album_id, 'album_name':album_name, 'release_date':album_release_date
                    , 'total_tracks':album_total_tracks, 'url':album_url}
    album_details.append(album_element)

# %%
album_details
# Out:
# [{'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'album_name': 'Flowers',
#   'release_date': '2023-01-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '6Exo0MYoL3XammoTDeihFy',
#   'album_name': 'Die For You (Remix)',
#   'release_date': '2023-02-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Exo0MYoL3XammoTDeihFy'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '6cVfHBcp3AdpYY0bBglkLN',
#   'album_name': "Boy's a liar Pt. 2",
#   'release_date': '2023-02-03',
#   'total_tracks': 2,
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-03-03T10:15:38Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
# ...

# %%
artist_details=[]
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict={'artist_id': artist['id'], 'artist_name':artist['name'], 'external_uri':artist['uri']}
                artist_details.append(artist_dict)

# %%
artist_details
# Out:
# [{'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '78rUTD7y6Cy67W1RVzYs7t',
#   'artist_name': 'PinkPantheress',
#   'external_uri': 'spotify:artist:78rUTD7y6Cy67W1RVzYs7t'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_added = row['added_at']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    
    song_element = {'song_id':song_id, 'song_name':song_name, 'song_added':song_added, 'duration':song_duration
                   , 'url':song_url, 'popularity':song_popularity, 'album_id': album_id, 'artist_id':artist_id}
    
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0yLdNVWF3Srea0uzk55zFn',
#   'song_name': 'Flowers',
#   'song_added': '2023-03-03T10:15:38Z',
#   'duration': 200454,
#   'url': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn',
#   'popularity': 100,
#   'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '0DWdj2oZMBFSzRsi2Cvfzf',
#   'song_name': 'TQG',
#   'song_added': '2023-03-03T10:15:38Z',
#   'duration': 197933,
#   'url': 'https://open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf',
#   'popularity': 88,
#   'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '7oDd86yk8itslrA9HRP2ki',
#   'song_name': 'Die For You - Remix',
#   'song_added': '2023-03-03T10:15:38Z',
#   'duration': 232857,
#   'url': 'https://open.spotify.com/track/7oDd86yk8itslrA9HRP2ki',
#   'popularity': 88,
#   'album_id': '6Exo0MYoL3XammoTDeihFy',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_details)

# %%
album_df.head()
# Out:
#                  album_id           album_name release_date  total_tracks  \
# 0  7I0tjwFtxUwBC1vgyeMAax              Flowers   2023-01-13             1
# 1  4kS7bSuU0Jm9LYMosFU2x5   MAÑANA SERÁ BONITO   2023-02-24            17
# 2  6Exo0MYoL3XammoTDeihFy  Die For You (Remix)   2023-02-24             1
# 3  1nrVofqDRs7cpWXJ49qTnP                  SOS   2022-12-08            23
# 4  6cVfHBcp3AdpYY0bBglkLN   Boy's a liar Pt. 2   2023-02-03             2
#
#                                                  url
# 0  https://open.spotify.com/album/7I0tjwFtxUwBC1v...
# 1  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2  https://open.spotify.com/album/6Exo0MYoL3Xammo...
# 3  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 4  https://open.spotify.com/album/6cVfHBcp3AdpYY0...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      48 non-null     object
#  1   album_name    48 non-null     object
#  2   release_date  48 non-null     object
#  3   total_tracks  48 non-null     int64
#  4   url           48 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
artist_df = pd.DataFrame.from_dict(artist_details)

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6    Miley Cyrus
# 1  790FomKkXshlbRYZFtlgla        KAROL G
# 2  0EmeFodog0BfCgMzAIvKQp        Shakira
# 3  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 4  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
#
#                             external_uri
# 0  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 1  spotify:artist:790FomKkXshlbRYZFtlgla
# 2  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 3  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ
# 4  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     76 non-null     object
#  1   artist_name   76 non-null     object
#  2   external_uri  76 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     58 non-null     object
#  1   artist_name   58 non-null     object
#  2   external_uri  58 non-null     object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id            song_name            song_added  \
# 0  0yLdNVWF3Srea0uzk55zFn              Flowers  2023-03-03T10:15:38Z
# 1  0DWdj2oZMBFSzRsi2Cvfzf                  TQG  2023-03-03T10:15:38Z
# 2  7oDd86yk8itslrA9HRP2ki  Die For You - Remix  2023-03-03T10:15:38Z
# 3  1Qrg8KqiBpW07V7PNxwwwL            Kill Bill  2023-03-03T10:15:38Z
# 4  6AQbmUe0Qwf5PZnt4HmTXv   Boy's a liar Pt. 2  2023-03-03T10:15:38Z
#
#    duration                                                url  popularity  \
# 0    200454  https://open.spotify.com/track/0yLdNVWF3Srea0u...         100
# 1    197933  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          88
# 2    232857  https://open.spotify.com/track/7oDd86yk8itslrA...          88
# 3    153946  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          92
# 4    131013  https://open.spotify.com/track/6AQbmUe0Qwf5PZn...          93
#
#                  album_id               artist_id
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     50 non-null     object
#  1   song_name   50 non-null     object
#  2   song_added  50 non-null     object
#  3   duration    50 non-null     int64
#  4   url         50 non-null     object
#  5   popularity  50 non-null     int64
#  6   album_id    50 non-null     object
#  7   artist_id   50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      48 non-null     object
#  1   album_name    48 non-null     object
#  2   release_date  48 non-null     object
#  3   total_tracks  48 non-null     int64
#  4   url           48 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\patra\AppData\Local\Temp\ipykernel_4932\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      48 non-null     object
#  1   album_name    48 non-null     object
#  2   release_date  48 non-null     datetime64[ns]
#  3   total_tracks  48 non-null     int64
#  4   url           48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     50 non-null     object
#  1   song_name   50 non-null     object
#  2   song_added  50 non-null     object
#  3   duration    50 non-null     int64
#  4   url         50 non-null     object
#  5   popularity  50 non-null     int64
#  6   album_id    50 non-null     object
#  7   artist_id   50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   song_id     50 non-null     object
#  1   song_name   50 non-null     object
#  2   song_added  50 non-null     datetime64[ns, UTC]
#  3   duration    50 non-null     int64
#  4   url         50 non-null     object
#  5   popularity  50 non-null     int64
#  6   album_id    50 non-null     object
#  7   artist_id   50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
